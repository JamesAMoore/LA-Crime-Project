# %% [markdown]
# # Los Angeles Crime Data Analysis

# %% [markdown]
# This is a project analyzing crime data in Los Angeles between 2020 and 2023.
#
# The data used can be found on kaggle [here](https://www.kaggle.com/datasets/venkatsairo4899/los-angeles-crime-data-2020-2023).

# %% [markdown]
# ## Questions
#
# 1. Which Los Angeles areas have the highest amount of reported crime?
# 2. What crimes are reported the most?
# 3. How many crimes are reported every year?
# 4. What are the trends in the reported crimes from 2020-2023.

# %% [markdown]
# ## Notebook Content
#
# 1. Step 1: Import Libraries
# 2. Step 2: Reading + Exploring the Data
# 3. Step 3: Data Cleaning
# 4. Step 4: Data Analysis + Visualizations
# 5. 2020 - 2023 Los Angeles Crime Data Analysis Results

# %% [markdown]
# ## Step 1: Import Libraries

# %%
#import necessary libraries

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 2: Reading + Exploring the Data

# %%
#read the csv file the data is contained in

df = pd.read_csv(r'C:\Users\James\Documents\Python Scripts\Crime_Data_from_2020_to_Present.csv')

# %%
df
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230
# 1       190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330
# 2       200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200
# 3       191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730
# 4       191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415
# ...           ...                     ...                     ...       ...
# 757136  231604807  01/27/2023 12:00:00 AM  01/26/2023 12:00:00 AM      1800
# 757137  231606525  03/22/2023 12:00:00 AM  03/22/2023 12:00:00 AM      1000
# 757138  231210064  04/12/2023 12:00:00 AM  04/12/2023 12:00:00 AM      1630
# 757139  230115220  07/02/2023 12:00:00 AM  07/01/2023 12:00:00 AM         1
# 757140  230906458  03/05/2023 12:00:00 AM  03/05/2023 12:00:00 AM       900
#
# ...

# %%
#check the columns the data is contained in
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757141 entries, 0 to 757140
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           757141 non-null  int64
#  1   Date Rptd       757141 non-null  object
#  2   DATE OCC        757141 non-null  object
#  3   TIME OCC        757141 non-null  int64
#  4   AREA            757141 non-null  int64
#  5   AREA NAME       757141 non-null  object
#  6   Rpt Dist No     757141 non-null  int64
#  7   Part 1-2        757141 non-null  int64
#  8   Crm Cd          757141 non-null  int64
#  9   Crm Cd Desc     757141 non-null  object
#  10  Mocodes         653226 non-null  object
#  11  Vict Age        757141 non-null  int64
#  12  Vict Sex        658230 non-null  object
#  13  Vict Descent    658224 non-null  object
#  14  Premis Cd       757132 non-null  float64
#  15  Premis Desc     756699 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 28)

# %%
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2  200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200     1
# 3  191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730    15
# 4  191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415    19
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Southwest          377         2     624
# 1      Central          163         2     624
# 2      Central          155         2     845
# 3  N Hollywood         1543         2     745
# 4      Mission         1998         2     740
#
#                                          Crm Cd Desc         Mocodes  \
# 0                           BATTERY - SIMPLE ASSAULT       0444 0913
# 1                           BATTERY - SIMPLE ASSAULT  0416 1822 1414
# ...

# %%
df.columns

# %% [markdown]
# ## Step 3: Data Cleaning

# %%
#convert dates from objects to dates

df['Date Rptd'] = pd.to_datetime(df['Date Rptd'])
df['DATE OCC'] = pd.to_datetime(df['DATE OCC'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757141 entries, 0 to 757140
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           757141 non-null  int64
#  1   Date Rptd       757141 non-null  datetime64[ns]
#  2   DATE OCC        757141 non-null  datetime64[ns]
#  3   TIME OCC        757141 non-null  int64
#  4   AREA            757141 non-null  int64
#  5   AREA NAME       757141 non-null  object
#  6   Rpt Dist No     757141 non-null  int64
#  7   Part 1-2        757141 non-null  int64
#  8   Crm Cd          757141 non-null  int64
#  9   Crm Cd Desc     757141 non-null  object
#  10  Mocodes         653226 non-null  object
#  11  Vict Age        757141 non-null  int64
#  12  Vict Sex        658230 non-null  object
#  13  Vict Descent    658224 non-null  object
#  14  Premis Cd       757132 non-null  float64
#  15  Premis Desc     756699 non-null  object
# ...

# %%
#drop any duplicates data may have
df.drop_duplicates()
# Out:
#             DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0        10304468 2020-01-08 2020-01-08      2230     3    Southwest
# 1       190101086 2020-01-02 2020-01-01       330     1      Central
# 2       200110444 2020-04-14 2020-02-13      1200     1      Central
# 3       191501505 2020-01-01 2020-01-01      1730    15  N Hollywood
# 4       191921269 2020-01-01 2020-01-01       415    19      Mission
# ...           ...        ...        ...       ...   ...          ...
# 757136  231604807 2023-01-27 2023-01-26      1800    16     Foothill
# 757137  231606525 2023-03-22 2023-03-22      1000    16     Foothill
# 757138  231210064 2023-04-12 2023-04-12      1630    12  77th Street
# 757139  230115220 2023-07-02 2023-07-01         1     1      Central
# 757140  230906458 2023-03-05 2023-03-05       900     9     Van Nuys
#
#         Rpt Dist No  Part 1-2  Crm Cd  \
# 0               377         2     624
# 1               163         2     624
# ...

# %%
cd4 = df['Crm Cd 4'].unique()
cd4
# Out:
# array([ nan, 998., 930., 821., 910., 999., 946.])

# %%
#Drop columns that are not going to be used
columns_to_drop = ['Crm Cd 4', 'Crm Cd 3', 'Crm Cd 2', 'LAT', 'LON', 'Cross Street']

# %%
pd.DataFrame(df.isnull().sum(), columns=['nulls']).rename_axis('columns')
# Out:
#                  nulls
# columns
# DR_NO                0
# Date Rptd            0
# DATE OCC             0
# TIME OCC             0
# AREA                 0
# AREA NAME            0
# Rpt Dist No          0
# Part 1-2             0
# Crm Cd               0
# Crm Cd Desc          0
# Mocodes         103915
# Vict Age             0
# Vict Sex         98911
# Vict Descent     98917
# Premis Cd            9
# Premis Desc        442
# Weapon Used Cd  494062
# Weapon Desc     494062
# Status               0
# Status Desc          0
# Crm Cd 1            10
# Crm Cd 2        701125
# Crm Cd 3        755269
# Crm Cd 4        757085
# LOCATION             0
# Cross Street    635409
# LAT                  0
# LON                  0

# %%
df = df.drop(columns = columns_to_drop)

# %%
df.head()
# Out:
#        DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  Rpt Dist No  \
# 0   10304468 2020-01-08 2020-01-08      2230     3    Southwest          377
# 1  190101086 2020-01-02 2020-01-01       330     1      Central          163
# 2  200110444 2020-04-14 2020-02-13      1200     1      Central          155
# 3  191501505 2020-01-01 2020-01-01      1730    15  N Hollywood         1543
# 4  191921269 2020-01-01 2020-01-01       415    19      Mission         1998
#
#    Part 1-2  Crm Cd                                        Crm Cd Desc  \
# 0         2     624                           BATTERY - SIMPLE ASSAULT
# 1         2     624                           BATTERY - SIMPLE ASSAULT
# 2         2     845          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 3         2     745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4         2     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
#           Mocodes  Vict Age Vict Sex Vict Descent  Premis Cd  \
# ...

# %% [markdown]
# ## Step 4: Data Analysis + Visualizations

# %% [markdown]
# ## Question 1: Which Los Angeles areas have the highest amount of reported crime?

# %%
#What areas have the most crime reports?

top_crime_areas = pd.DataFrame(df['AREA NAME'].value_counts()).rename({"AREA NAME": 'Cases Reported'}, axis = 1).rename_axis("Location").head(10)
top_crime_areas.style.bar()
# Out:
# <style type="text/css">
# #T_d1d05_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_d1d05_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 94.3%, transparent 94.3%);
# }
# #T_d1d05_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 86.8%, transparent 86.8%);
# }
# #T_d1d05_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 83.2%, transparent 83.2%);
# }
# #T_d1d05_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 79.4%, transparent 79.4%);
# }
# #T_d1d05_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 76.4%, transparent 76.4%);
# }
# #T_d1d05_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 75.6%, transparent 75.6%);
# }
# #T_d1d05_row7_col0, #T_d1d05_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 74.2%, transparent 74.2%);
# }
# ...

# %%
top_crime_areas = top_crime_areas.sort_values(by='Cases Reported', ascending = False).head(10)

plt.figure(figsize=(10,7))
sns.barplot(x=top_crime_areas.index, y='Cases Reported', palette='plasma', data=top_crime_areas)

plt.xlabel('Location')
plt.ylabel('Cases Reported')
plt.title('Top 10 areas with the most crimes reported')

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Analysis shows the the areas with the highest number of reported crimes from 2020 to 2023 are:
#
# 1. Central (total of 50801 reported crimes)
# 2. 77th Street (total of 47926 reported crimes)
# 3. Pacific (total of 44118 reported crimes)
# 4. Southwest (total of 42282 reported crimes)
# 5. Hollywood (total of 40354 reported crimes)
# 6. Southeast (total of 38117 reported crimes)
# 7. Olympic (total 38409 of reported crimes)
# 8. Newton (total of 37691 reported crimes)
# 9. N Hollywood (total of 37687 reported crimes)
# 10. Wilshire (total of 35761 reported crimes)

# %% [markdown]
# ## Question 2: What are the most frequently reported crimes?

# %%
# Determine the top 10 crimes areas
top_crime_areas = df['AREA NAME'].value_counts().head(10).index

# Filter the data to include only the top 10 crime areas
data_top_crime = df[df['AREA NAME'].isin(top_crime_areas)]

# Determine the top 5 most common crimes
top_crimes = data_top_crime['Crm Cd Desc'].value_counts().head(5).index

# Filter the data to include only the top 5 crimes
data_top_crimes = data_top_crime[data_top_crime['Crm Cd Desc'].isin(top_crimes)]

# Determing the order of areas based on the most common crimes
area_order = data_top_crime.groupby('AREA NAME')['Crm Cd Desc'].count().sort_values(ascending = False).head(10).index

# Create the count plot
plt.figure(figsize=(10,6))
ax = sns.countplot(data=data_top_crimes, x='AREA NAME', hue='Crm Cd Desc', palette='plasma', order=area_order)

# Customize legend to decrease size
legend = ax.legend(title='Crimes')
custom_legend_labels = legend.texts
custom_legend_labels[2].set_text('Assault w/ Deadly Weapon')
custom_legend_labels[4].set_text('Vandalism - Felony $400+')

# Adjust y-axis values 
ax.set_ylim(1000, 7500)


plt.xlabel('Location')
plt.ylabel('Cases Reported')
plt.title('Crime Distribution for Top 10 Areas')

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# __Stolen Vehicle__ was the most reported crime in every area except for __Central and Hollywood__. __Burglary from Vehicle__ was the most reported in __Central__ and __Battery - Simple Assault__ was the most reported crime in __Hollywood__.

# %% [markdown]
# ## Question 3: How many crimes are reported anually in Los Angeles?

# %%
# Extract the years from the data
df['year'] = df['DATE OCC'].dt.year
df['year'].unique()
# Out:
# array([2020, 2021, 2022, 2023], dtype=int64)

# %%
pd.DataFrame(df['year'].value_counts()).rename({'year': 'Cases Reported'}, axis=1).rename_axis('Year')
# Out:
#       Cases Reported
# Year
# 2022          233692
# 2021          209166
# 2020          199291
# 2023          114992

# %% [markdown]
# The amount of crimes have __increased__ yearly in Los Angeles. __2020__ had 199291 reported crimes, __2021__ saw an increase of __9875__ resulting in a total of __209166__. __2022__ saw an increase of __24256__ compared to the previous year resulting in a total of __233692__.

# %% [markdown]
# ## Question 4: What are the trends in the reported crimes between 2020-2023
#
# 1. What are the trends in the categories of reported crimes?
# 2. Did crime rates increase or decrease?

# %% [markdown]
# ### 1. What are the categorical trends of reported crimes?

# %%
# Determine the top 5 most common crimes overall
top_crimes = df['Crm Cd Desc'].value_counts().head(5).index

# Filter the data to include only the top 5 crimes
data_top_crimes = df[df['Crm Cd Desc'].isin(top_crimes)]

# Create the countplot
plt.figure(figsize=(10, 6))
sns.countplot(data=data_top_crimes, x='year', hue='Crm Cd Desc', palette='plasma')

plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Distribution of Top 5 Crimes per Year')

plt.tight_layout()
plt.show()

# %% [markdown]
# __Stolen Vehicle__ has been the most reported crime every year from 2020 until now. With the second most reported being __Battery - Simple Assault__.

# %% [markdown]
# ### 2. Did crime rates increase or de
